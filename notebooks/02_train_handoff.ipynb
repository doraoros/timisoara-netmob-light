# %% [markdown]
# # 02 — Antrenare modele handoff
#
# Echivalent cu `python -m src.models.train_handoff_models`

# %%
import sys
from pathlib import Path
nb_dir = Path.cwd()
if (nb_dir / "_project.py").is_file():
    sys.path.insert(0, str(nb_dir))
from _project import setup_path
setup_path()

# %%
from src.models.train_handoff_models import main
main()

# %%
import json
import pandas as pd
from pathlib import Path
from src.config import HANDOFF_METRICS_JSON, REPORTS_TEXT

with open(HANDOFF_METRICS_JSON) as f:
    m = json.load(f)
pd.read_csv(REPORTS_TEXT / "tables" / "model_metrics_holdout.csv")
